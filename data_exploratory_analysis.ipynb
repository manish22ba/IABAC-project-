# %% [markdown]
# ## Exploratory Data Analysis
# Under EDA , will be performing the below compoments :
# - Understanding the variables
# - Analyzing relationships between variables

# %%
# Importing the necessary libraries
import pandas as pd #Data processing and I/O operations 
import numpy as np #Linera Algebra
import seaborn as sns #Data plotting
import matplotlib.pyplot as plt #Data plotting
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

# %% [markdown]
# ## Import data

# %%
df = pd.read_excel("INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls")

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %%
df.shape
# Out:
# (1200, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
# EmpNumber                       1200 non-null object
# Age                             1200 non-null int64
# Gender                          1200 non-null object
# EducationBackground             1200 non-null object
# MaritalStatus                   1200 non-null object
# EmpDepartment                   1200 non-null object
# EmpJobRole                      1200 non-null object
# BusinessTravelFrequency         1200 non-null object
# DistanceFromHome                1200 non-null int64
# EmpEducationLevel               1200 non-null int64
# EmpEnvironmentSatisfaction      1200 non-null int64
# EmpHourlyRate                   1200 non-null int64
# EmpJobInvolvement               1200 non-null int64
# EmpJobLevel                     1200 non-null int64
# EmpJobSatisfaction              1200 non-null int64
# NumCompaniesWorked              1200 non-null int64
# ...

# %%
df.columns
# Out:
# Index(['EmpNumber', 'Age', 'Gender', 'EducationBackground', 'MaritalStatus',
#        'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency',
#        'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction',
#        'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel',
#        'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'PerformanceRating'],
#       dtype='object')

# %%
# Looking for missing data
df.isna().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %% [markdown]
# ## Data processing Insights  :
# - The dataset consists of 28 independent variable (inputs) with dependent variable(output) i.e PerformanceRating.
# - By seeing the shape of dataframe we can say there are total 1200 rows
# - There is no missing value observed in the dataset.

# %%
df.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %% [markdown]
# # Analysis of Department wise Perfomance

# %%
# A new pandas Dataframe is created to analyze department wise performance as per the problem statment.
dep = df.iloc[:,[5,27]].copy()
dep_perf = dep.copy()

# %%
# Finding out the mean performance of all the departments and plotting its bar graph using seaborn.
dep_perf.groupby(by='EmpDepartment')['PerformanceRating'].mean()
# Out:
# EmpDepartment
# Data Science              3.050000
# Development               3.085873
# Finance                   2.775510
# Human Resources           2.925926
# Research & Development    2.921283
# Sales                     2.860590
# Name: PerformanceRating, dtype: float64

# %% [markdown]
# # Pie plot

# %%
pie, ax = plt.subplots(figsize=[10,6])
labels = (pd.Series(dep_perf.EmpDepartment.unique())).sort_values(ascending=True)
plt.pie(x =dep_perf.groupby(by='EmpDepartment')['PerformanceRating'].mean(), autopct="%.2f%%", explode=[0.05]*6, labels=labels, pctdistance=0.5)
plt.title("Mean performance of all the departments", fontsize=14);
pie.savefig("Mean_performance_pie.png")

# %%
# Analyzing each department separately with target variable
dep_perf.groupby(by='EmpDepartment')['PerformanceRating'].value_counts()
# Out:
# EmpDepartment           PerformanceRating
# Data Science            3                     17
#                         4                      2
#                         2                      1
# Development             3                    304
#                         4                     44
#                         2                     13
# Finance                 3                     30
#                         2                     15
#                         4                      4
# Human Resources         3                     38
#                         2                     10
#                         4                      6
# Research & Development  3                    234
#                         2                     68
#                         4                     41
# Sales                   3                    251
#                         2                     87
#                         4                     35
# ...

# %% [markdown]
# # Bar plot

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.countplot(df.EmpDepartment,hue=df.PerformanceRating)
plt.xlabel("Employee Department", size=20)
plt.ylabel("Count of Employee's", size=20)
plt.tight_layout()
plt.savefig("Grouped_Employee_Department.png")

# %% [markdown]
# ## Based on the above Pie and Bar plot , below are the observations
#
# '**Pie plot Insights**'
# - '**HIGHEST**' Performance percentage is of Development Department i.e 17.51%
# - '**LOWEST**' Performance percentage is of Finance Department i.e 15.75%
#
# '**BarPlot Insights**'
# - Employees provided with PerformanceRating '**Performance Score-2**' is highest in Sales, Research & Development departments.
# - Employees provided with PerformanceRating '**Performance Score-3**' is highest in Development department.
# - Employees provided with PerformanceRating '**Performance  Score-4**' is highest in Development department.

# %%
plt.figure(figsize=(30,10))
temp_df = pd.DataFrame()
temp_df['rating_2'] = df[df['PerformanceRating'] == 2]['EmpJobRole'].value_counts()
temp_df['rating_3'] = df[df['PerformanceRating'] == 3]['EmpJobRole'].value_counts()
temp_df['rating_4'] = df[df['PerformanceRating'] == 4]['EmpJobRole'].value_counts()
plt.tight_layout()
temp_df.plot.bar(title = 'Relation b/w EmpJobRole and PerformanceRating');
plt.savefig("EmpJobRole_and_PerformanceRating.png")

# %% [markdown]
# # Insights from the above graph
# - Employee who are less inolved or intermediatly involved in their jobs role have peformance rating more towards 3 and 2 whereas sales and finance & developers seems to enjoy their jobs.

# %% [markdown]
# ## Some numerical data exploratory analysis to understand the dataset well!

# %%
temp_df = pd.DataFrame()
temp_df['rating_2'] = (df[df['PerformanceRating'] == 2][['PerformanceRating','Age']].describe())['Age']
temp_df['rating_3'] = (df[df['PerformanceRating'] == 3][['PerformanceRating','Age']].describe())['Age']
temp_df['rating_4'] = (df[df['PerformanceRating'] == 4][['PerformanceRating','Age']].describe())['Age']

temp_df
# Out:
#          rating_2    rating_3   rating_4
# count  194.000000  874.000000  132.00000
# mean    37.804124   36.784897   36.50000
# std      9.269862    9.002199    9.36495
# min     21.000000   18.000000   18.00000
# 25%     31.000000   30.000000   30.00000
# 50%     36.000000   35.000000   36.00000
# 75%     44.000000   43.000000   42.00000
# max     59.000000   60.000000   60.00000

# %%
plt.figure(figsize=(10,10))
temp_df.drop(['count','25%','50%','75%']).plot.bar(title = "'Relation b/w Age and PerformanceRating'");
plt.savefig("Age_and_PerformanceRating.png")

# %% [markdown]
# # Insights from the above graph
# - Rating 4 employes have less age and very active in their work then the higher level employess

# %% [markdown]
# # We will now found top 3 Important Factors effecting employee performance
# - For findig the top 3 features we will be using some '**Feature Selection Techniques**''and select the best/important features.

# %% [markdown]
# ## Data Processing/ Data Munging

# %%
#convert the Categorical Variable into Numerical by using LabelEncoder
from sklearn.preprocessing import LabelEncoder
encode=LabelEncoder()
lab_enc_Dataset=df.apply(encode.fit_transform)
lab_enc_Dataset.head()
# Out:
#    EmpNumber  Age  Gender  EducationBackground  MaritalStatus  EmpDepartment  \
# 0          0   14       1                    2              2              5
# 1          1   29       1                    2              2              5
# 2          2   22       1                    1              1              5
# 3          3   23       1                    0              0              3
# 4          4   42       1                    2              2              5
#
#    EmpJobRole  BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0          13                        2                 9                  2
# 1          13                        2                13                  3
# 2          13                        1                 4                  3
# 3           8                        2                 9                  3
# 4          13                        2                15                  3
#
# ...

# %%
# Select features based on k highest scores.
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
lab_enc_Dataset.shape
# Out:
# (1200, 28)

# %%
#independent_features
X= lab_enc_Dataset.iloc[:,:-1]

#dependent_features
Y = lab_enc_Dataset['PerformanceRating']

# %%
### Applying SelectKBest Algorithm
ordered_rank_features=SelectKBest(score_func=chi2,k=20)
ordered_feature=ordered_rank_features.fit(X,Y)

# %%
df_VALUES=pd.DataFrame(ordered_feature.scores_,columns=["Score"])
columns_name=pd.DataFrame(X.columns)

# %%
features_rank=pd.concat([columns_name,df_VALUES],axis=1)
features_rank.columns=['Features','k_values']
features_rank
# Out:
#                         Features     k_values
# 0                      EmpNumber     2.560357
# 1                            Age    10.089648
# 2                         Gender     0.064501
# 3            EducationBackground     0.151941
# 4                  MaritalStatus     1.232011
# 5                  EmpDepartment    46.787010
# 6                     EmpJobRole    35.896167
# 7        BusinessTravelFrequency     1.011364
# 8               DistanceFromHome    20.933918
# 9              EmpEducationLevel     0.479977
# 10    EmpEnvironmentSatisfaction   175.203015
# 11                 EmpHourlyRate    32.768771
# 12             EmpJobInvolvement     0.350320
# 13                   EmpJobLevel    12.144045
# 14            EmpJobSatisfaction     0.170826
# 15            NumCompaniesWorked     1.208359
# 16                      OverTime     7.963530
# 17      EmpLastSalaryHikePercent  1071.205856
# 18   EmpRelationshipSatisfaction     0.565559
# ...

# %%
features_rank.nlargest(5,'k_values')
# Out:
#                         Features     k_values
# 17      EmpLastSalaryHikePercent  1071.205856
# 24       YearsSinceLastPromotion   238.004284
# 10    EmpEnvironmentSatisfaction   175.203015
# 22  ExperienceYearsAtThisCompany   133.866393
# 23  ExperienceYearsInCurrentRole   120.860036

# %% [markdown]
# ### Insigths from the above SelectKBest Algorithm
# - The above mentioned features are top 5 Features with '**k highest values**'

# %% [markdown]
# ## Feature Importance
# - Now by Feature importance we will see the values for each feature of our data,the higher the score more relevant it is.

# %%
from sklearn.ensemble import ExtraTreesClassifier
model=ExtraTreesClassifier()
model.fit(X,Y)
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#                      max_depth=None, max_features='auto', max_leaf_nodes=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#                      oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
print(model.feature_importances_)
# Out:
# [0.03587445 0.02796363 0.02081411 0.02830122 0.02268774 0.04288667
#  0.02746983 0.02363227 0.03066406 0.02654664 0.14056306 0.02757595
#  0.02679933 0.02146808 0.02466939 0.02483689 0.01665947 0.14881719
#  0.0240767  0.02481929 0.0246252  0.03136461 0.02882829 0.03944576
#  0.06494225 0.03269096 0.01097696]

# %%
ranked_features=pd.Series(model.feature_importances_,index=X.columns)
ranked_features.nlargest(10).plot(kind='barh', title = 'Feature importance’s coeffecients plot')
plt.show()

# %% [markdown]
# ### Insigths from the above Feature Importance
# We can observe from the TOP:5 features which affect the Performance Rating of an Employee are below :
# 1.  EmpLastSalaryHikePercent
# 2.  YearsSinceLastPromotion
# 3.	EmpEnvironmentSatisfaction
# 4.	ExperienceYearsAtThisCompany
# 5.	ExperienceYearsInCurrentRole

# %% [markdown]
# # Correlation of the Dataset
# - we will check if there is any correlation between these features , accordingly we will define our top three(3) featuresm

# %%
df.corr()
# Out:
#                                    Age  DistanceFromHome  EmpEducationLevel  \
# Age                           1.000000          0.020937           0.207313
# DistanceFromHome              0.020937          1.000000           0.045856
# EmpEducationLevel             0.207313          0.045856           1.000000
# EmpEnvironmentSatisfaction    0.013814         -0.017719          -0.037103
# EmpHourlyRate                 0.062867          0.013730           0.014095
# EmpJobInvolvement             0.027216          0.003231           0.027544
# EmpJobLevel                   0.509139          0.017270           0.100734
# EmpJobSatisfaction           -0.002436         -0.003036           0.000357
# NumCompaniesWorked            0.284408         -0.021411           0.128674
# EmpLastSalaryHikePercent     -0.006105          0.044974           0.002358
# EmpRelationshipSatisfaction   0.049749         -0.009509          -0.016690
# ...

# %%
# plotting the Co-relation between the Independent Variables
corr= df.iloc[:,:-1].corr()
top_features=corr.index
plt.figure(figsize=(20,20))
sns.heatmap(df[top_features].corr(),annot=True)
#plt.tight_layout()

# %% [markdown]
# ## Conculsion for Case-2 Problem Statement :
#
#    In addition to the above results captured based on the '**SelectKBest Algorithm**' and '**Feature Importance**' techniques.
#    Correlation values for the Top-5 features are as below :
# 1.  EmpLastSalaryHikePercent : 0.333722
# 2.  YearsSinceLastPromotion : -0.167629
# 3.	EmpEnvironmentSatisfaction : 0.395561
# 4.	ExperienceYearsAtThisCompany : -0.111645
# 5.	ExperienceYearsInCurrentRole : -0.147638
#
# - We can observe the features are not much correlated to each other.
#
# So based on the above values as well we can conclude that below are the TOP 3 features that will affect the Employee Performance rating criteria :
#  1. Employee EnvironmentSatisfaction, 2. Employee Last Salary Hike Percent and 3. Years Since Last Promotion
